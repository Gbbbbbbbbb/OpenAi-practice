# %%
from langchain.chat_models import ChatOpenAI
from langchain.callbacks import get_openai_callback

chat = ChatOpenAI(model_name="gpt-5-nano", temperature=1,)##streaming=True, callbacks=[StreamingStdOutCallbackHandler()])


with get_openai_callback() as usage :
    a=chat.predict("what is the recipe for soju")
    b=chat.predict("what is the recipe for bread")
    print(a,b,"\n")
    print(usage)
# Out:
# Soju isn’t a single fixed recipe. Traditionally it’s a distilled rice-based spirit (around 20% ABV, sometimes higher or lower depending on brand). Modern soju often uses a neutral base spirit (made from rice, wheat, barley, or other starches) that’s diluted with water to around 16–25% ABV, sometimes with sweeteners or flavors. Because there isn’t one standard recipe and because distillation at home can be dangerous and in many places illegal without a license, I’ll outline safe options and an alternative you can try.
#
# Safety and legality note
# - Distilling alcohol at home can be dangerous (flammable vapors, methanol risk) and is illegal or tightly regulated in many areas without proper permits. Check your local laws before attempting anything like that.
# - If you just want to explore flavors or learn the concept, consider non-distilling options first.
#
# Non-distilling, learn-by-making alternative (makgeolli)
# If you’re interested in a traditional, non-distilled Korean rice drink with a similar rice-based vibe, you can try makgeolli. Here’s a basic, non-distilling approach:
#
# - Ingredients
#   - 2 cups cooked short-grain rice (steamed and cooled)
#   - 4 cups water
#   - 1–2 tablespoons nuruk (Korean fermentation starter) or 1 teaspoon active dry yeast
#   - Optional: a little sugar to taste
#
# - Equipment
#   - Clean glass jar or fermenting vessel
#   - Clean cloth or paper towel to cover
#   - Strainer
#
# - Method (high-level)
#   1) Cook the rice, then cool it to around body temperature.
#   2) In a clean jar, mix the cooled rice with water and the fermentation starter.
#   3) Cover with the cloth and leave at room temperature to ferment for about 5–7 days, stirring once daily.
#   4) Strain the liquid through a cheesecloth to remove solids. What remains is the makgeolli.
#   5) Chill and enjoy. It tastes milky and lightly fizzy; refrigerate and consume within about a week.
#
# Notes
# - Fermentation times and results vary with temperature and starter. If it smells off or shows obvious mold, discard.
# - You can adjust sweetness by adding a little sugar to taste after fermentation.
#
# If you want more help
# - Tell me your location and whether you want a distillation-based approach (and you’re prepared to handle the legal/safety requirements) or a non-distilled option like makgeolli.
# - I can tailor a safer, step-by-step plan or suggest store-bought alternatives to explore the flavor profile of soju. Here’s a straightforward basic white bread recipe. It makes one standard loaf.
#
# Ingredients
# - 3 1/2 cups (420–440 g) all-purpose or bread flour
# - 1 cup (240 ml) warm water (about 110°F / 43°C)
# - 2 Tbsp olive oil or melted butter (or neutral oil)
# - 1 Tbsp sugar or honey (optional, for flavor and browning)
# - 2 1/4 tsp active dry yeast (1 packet) or 1 1/2 tsp instant yeast
# - 1 1/2 tsp salt
#
# Method (active dry yeast)
# 1) Activate yeast: In a small bowl, mix warm water, sugar/honey, and yeast. Let sit 5–10 minutes until foamy.
# 2) Mix dry: In a large bowl, whisk flour and salt.
# 3) Combine: Add the yeast mixture and oil to the flour. Stir until a shaggy dough forms.
# 4) Knead: Turn out onto a floured surface and knead 8–10 minutes until smooth and elastic. Add a little flour if too sticky.
# 5) First rise: Lightly oil a bowl, place dough inside, cover, and let rise in a warm spot until doubled (about 1 hour).
# 6) Shape and second rise: Punch down, shape into a loaf, and place in a lightly oiled 9×5-inch loaf pan. Cover and let rise until the loaf crowns about 1 inch above the rim (30–45 minutes).
# 7) Bake: Preheat to 375°F (190°C). Bake 25–30 minutes until deep golden and the loaf sounds hollow when tapped.
# 8) Cool: Remove from pan and let cool on a rack before slicing.
#
# Instant yeast option (no proofing)
# - Mix flour, salt, and instant yeast directly, then add warm water and oil. Knead 6–8 minutes, rise as above, and bake.
#
# No-knead variation (very easy)
# - In a bowl, mix 3 cups flour, 1 1/2 cups water, 1/2–1 tsp instant yeast, 1 1/2 tsp salt. Stir until just combined. Let rest 12–18 hours at room temp. Shape and bake in a hot Dutch oven (450°F/230°C) for about 30–35 minutes with lid on, then 10–15 minutes uncovered for color.
#
# Tips
# - For crustier bread, bake on a preheated stone or in a Dutch oven.
# - You can swap in 1 cup of whole wheat flour for a lighter whole-wheat loaf; you may need a bit more water.
# - Store cooled loaf in a bag at room temperature for 2–3 days, or freeze for longer storage.
#
# If you tell me your bread type (white, whole wheat, sourdough, no-knead) or dietary needs, I can tailor a recipe.
#
# Tokens Used: 2228
# 	Prompt Tokens: 12
# 	Completion Tokens: 2216
# Successful Requests: 1
# Total Cost (USD): $0.0
