# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import PromptTemplate, ChatPromptTemplate
from langchain.callbacks import StreamingStdOutCallbackHandler

chat = ChatOpenAI(model_name="gpt-5-nano", temperature=1, streaming=True, callbacks=[StreamingStdOutCallbackHandler()])


chef_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a world-class international chef. You create easy to follow recipes for any type of cuisins with easy to find ingredients"),
    ("human", "I want to cook {cuisine} food.")
])

chef_chain = chef_prompt

# %%
veg_chef_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a vegetarian chef specialized on making traditional recipes vegetarian. You find alternative ingredients and explain their preparation. You don't redically modify the recipe, If there is no alternative for a food just say you don't know how to replace it."),
    ("human", "{recipe}")
])

veg_chain = veg_chef_prompt | chat

final_chain = {"recipe" : chef_chain} | veg_chain

final_chain.invoke ({"cuisine": "indian"})
# Out:
# AIMessage(content='Dal Tadka is a great quick vegetarian option. Here is a precise, step-by-step plan you can follow in about 25–30 minutes.\n\nIngredients (for 2 servings)\n- 1 cup red lentils (masoor dal) or yellow split lentils\n- 2 cups water (plus a splash as needed)\n- 1/2 teaspoon turmeric\n- 1/2 teaspoon salt (adjust to taste)\n- 1 tablespoon oil (or ghee, if you prefer; use oil for vegan)\n- 1/2 teaspoon cumin seeds\n- Optional: 1/4 teaspoon mustard seeds\n- 1/2 small onion, finely chopped\n- 2 cloves garlic, minced\n- 1 inch piece ginger, minced\n- 1 small tomato, chopped\n- Optional chili powder or fresh chili to taste\n- Fresh cilantro, chopped (for garnish)\n\nStep-by-step\n1) Rinse lentils and cook\n- Rinse 1 cup lentils until water runs clear.\n- In a pot, add lentils, 2 cups water, turmeric, and salt.\n- Bring to a boil, then reduce to a simmer. Cook uncovered, stirring occasionally, about 10–15 minutes, until lentils are soft and breaking apart. If needed, add a splash more water to reach a loose consistency.\n\n2) Prepare the tadka (tempered spices) on the side\n- In a small pan, heat 1 tablespoon oil over medium heat.\n- Add cumin seeds (and optional mustard seeds); let them crackle 15–20 seconds.\n- Add chopped onion; sauté until translucent and just starting to brown (about 3–5 minutes).\n- Add garlic and ginger; sauté about 1 minute until fragrant.\n- Add chopped tomato and a pinch of chili (to taste); cook until tomato breaks down and oil starts to separate from the mixture (about 3–4 minutes).\n\n3) Finish the dal\n- Pour the tadka over the cooked lentils. Stir to combine.\n- Simmer 2–3 minutes to meld flavors. Taste and adjust salt if needed.\n- Optional: finish with a pinch of garam masala and a quick squeeze of lemon or lime.\n\n4) Serve\n- Garnish with chopped cilantro.\n- Serve with basmati rice or your choice of flatbread (naan or roti). If you like a creamy texture, mash a few lentils gently with the back of a spoon.\n\nNotes and substitutions\n- Vegan/vegetarian: this version uses oil, so it’s vegan-friendly.\n- Gluten-free: this dish is gluten-free; pair with rice or gluten-free bread.\n- If you don’t have red lentils, yellow split lentils work too, but cooking times may vary slightly.\n\nWould you like me to tailor this further to your spice tolerance (mild/medium/fiery) or adjust for any dietary needs? If you have certain ingredients on hand, I can adapt the plan accordingly.')
