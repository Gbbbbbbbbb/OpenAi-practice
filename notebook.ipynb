# %%
from langchain.memory import ConversationKGMemory
from langchain.chat_models import ChatOpenAI

llm = ChatOpenAI(temperature=0.1)

memory = ConversationKGMemory(
    llm=llm,
    return_messages=True,)

def add_message(input,output) : 
    memory.save_context({"input": input}, {"output": output})


add_message("안녕 나는 전기범이야, 나는 대한민국에 살고있고","정말 멋진데")

# %%
memory.load_memory_variables({"input":"who is 전기범?"})
# Out:
# {'history': [SystemMessage(content='On 전기범: 전기범 나는 대한민국에 살고있고.')]}

# %%
add_message("기범이는 돈까스를 좋아하고","멋지다!")

# %%
memory.load_memory_variables({"input":"기범이는 뭐 좋아해?"})
# Out:
# {'history': [SystemMessage(content='On 기범이: 기범이 좋아하고 돈까스.')]}
