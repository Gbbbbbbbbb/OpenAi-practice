# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import PromptTemplate, ChatPromptTemplate
from langchain.callbacks import StreamingStdOutCallbackHandler

chat = ChatOpenAI(model_name="gpt-5-nano", temperature=1, streaming=True, callbacks=[StreamingStdOutCallbackHandler()])


chef_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a world-class international chef. You create easy to follow recipes for any type of cuisins with easy to find ingredients"),
    ("human", "I want to cook {cuisine} food.")
])

chef_chain = chef_prompt

# %%
veg_chef_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a vegetarian chef specialized on making traditional recipes vegetarian. You find alternative ingredients and explain their preparation. You don't redically modify the recipe, If there is no alternative for a food just say you don't know how to replace it."),
    ("human", "{recipe}")
])

veg_chain = veg_chef_prompt | chat

final_chain = {"recipe" : chef_chain} | veg_chain

final_chain.invoke ({"cuisine": "indian"})
# Out:
# Great choice. A classic and flavorful vegetarian Indian option to start with is Chana Masala (Chole). It’s pantry-friendly and pairs well with rice, roti, or bhature.
#
# Chana Masala (Chole) — serves 4
# Ingredients
# - 2 cups chickpeas (cooked) or 1 15-oz can, rinsed and drained
# - 1 medium onion, finely chopped
# - 2 medium tomatoes, finely chopped (or 1 cup tomato puree)
# - 3 garlic cloves, minced
# - 1 inch piece of ginger, grated
# - 1-2 green chilies (optional), finely chopped
# - 1 teaspoon cumin seeds
# - 1 teaspoon coriander powder
# - 1/2 teaspoon cumin powder
# - 1/2 teaspoon turmeric
# - 1 teaspoon garam masala
# - 1/2 teaspoon chili powder (adjust to heat preference)
# - 1 teaspoon amchur (dry mango powder) or juice of 1/2 lemon (for tang)
# - Salt to taste
# - 1-2 tablespoons oil
# - Fresh cilantro, chopped (for garnish)
# - Water as needed
#
# How to make it
# 1) If using dried chickpeas: soak overnight, then pressure-cook until tender. If using canned, rinse and drain well.
# 2) Heat oil in a pan over medium heat. Add cumin seeds and let them sizzle 20-30 seconds.
# 3) Add chopped onion. Sauté until golden brown, about 5-7 minutes.
# 4) Add garlic, ginger, and green chilies (if using). Sauté 1 minute.
# 5) Stir in coriander powder, cumin powder, turmeric, and chili powder. Cook 30 seconds to bloom the spices.
# 6) Add tomatoes (or tomato puree). Cook until the oil begins to separate from the masala, about 7-10 minutes.
# 7) Add chickpeas and about 1 cup water (adjust for desired gravy). Simmer 15-20 minutes so flavors meld.
# 8) Stir in garam masala, salt, and amchur (or lemon juice). Simmer 2-3 minutes more. Taste and adjust tang or salt as needed.
# 9) Garnish with cilantro and serve with rice, roti, or bhature.
#
# Tips and substitutions
# - No chickpeas? If you don’t have chickpeas, I don’t know a perfect replacement that keeps the dish the same flavor, so it’s best to skip or try a different Indian curry with vegetables you have.
# - Amchur powder is used for tang. If you don’t have it, use lemon juice at the end.
# - For a creamier texture, you can blend a small portion of the chickpeas and mix back in, or stir in a little coconut milk at the end (adjust to taste).
# - Vegan/short on ghee: use a neutral oil or add a small amount of vegan butter, but ghee is traditional for depth if you have it.
# - Variations: add a handful of spinach at the end for a quick “Chana Palak” version, or toss in a few chopped cilantro stems with the cilantro garnish for extra aroma.
#
# Serving suggestions
# - Traditional: serve with basmati rice or bhature, and a side of fresh onion rings and lemon wedges.
# - If you want a lighter option, pair with steamed rice and a side of cucumber or tomato salad.
#
# Would you like me to tailor this to what you have on hand (different veggies, or no chickpeas), or suggest another quick Indian vegetarian dish?
# AIMessageChunk(content='Great choice. A classic and flavorful vegetarian Indian option to start with is Chana Masala (Chole). It’s pantry-friendly and pairs well with rice, roti, or bhature.\n\nChana Masala (Chole) — serves 4\nIngredients\n- 2 cups chickpeas (cooked) or 1 15-oz can, rinsed and drained\n- 1 medium onion, finely chopped\n- 2 medium tomatoes, finely chopped (or 1 cup tomato puree)\n- 3 garlic cloves, minced\n- 1 inch piece of ginger, grated\n- 1-2 green chilies (optional), finely chopped\n- 1 teaspoon cumin seeds\n- 1 teaspoon coriander powder\n- 1/2 teaspoon cumin powder\n- 1/2 teaspoon turmeric\n- 1 teaspoon garam masala\n- 1/2 teaspoon chili powder (adjust to heat preference)\n- 1 teaspoon amchur (dry mango powder) or juice of 1/2 lemon (for tang)\n- Salt to taste\n- 1-2 tablespoons oil\n- Fresh cilantro, chopped (for garnish)\n- Water as needed\n\nHow to make it\n1) If using dried chickpeas: soak overnight, then pressure-cook until tender. If using canned, rinse and drain well.\n2) Heat oil in a pan over medium heat. Add cumin seeds and let them sizzle 20-30 seconds.\n3) Add chopped onion. Sauté until golden brown, about 5-7 minutes.\n4) Add garlic, ginger, and green chilies (if using). Sauté 1 minute.\n5) Stir in coriander powder, cumin powder, turmeric, and chili powder. Cook 30 seconds to bloom the spices.\n6) Add tomatoes (or tomato puree). Cook until the oil begins to separate from the masala, about 7-10 minutes.\n7) Add chickpeas and about 1 cup water (adjust for desired gravy). Simmer 15-20 minutes so flavors meld.\n8) Stir in garam masala, salt, and amchur (or lemon juice). Simmer 2-3 minutes more. Taste and adjust tang or salt as needed.\n9) Garnish with cilantro and serve with rice, roti, or bhature.\n\nTips and substitutions\n- No chickpeas? If you don’t have chickpeas, I don’t know a perfect replacement that keeps the dish the same flavor, so it’s best to skip or try a different Indian curry with vegetables you have.\n- Amchur powder is used for tang. If you don’t have it, use lemon juice at the end.\n- For a creamier texture, you can blend a small portion of the chickpeas and mix back in, or stir in a little coconut milk at the end (adjust to taste).\n- Vegan/short on ghee: use a neutral oil or add a small amount of vegan butter, but ghee is traditional for depth if you have it.\n- Variations: add a handful of spinach at the end for a quick “Chana Palak” version, or toss in a few chopped cilantro stems with the cilantro garnish for extra aroma.\n\nServing suggestions\n- Traditional: serve with basmati rice or bhature, and a side of fresh onion rings and lemon wedges.\n- If you want a lighter option, pair with steamed rice and a side of cucumber or tomato salad.\n\nWould you like me to tailor this to what you have on hand (different veggies, or no chickpeas), or suggest another quick Indian vegetarian dish?')
