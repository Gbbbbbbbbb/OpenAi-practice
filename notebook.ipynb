# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts.few_shot import FewShotPromptTemplate
from langchain.callbacks import StreamingStdOutCallbackHandler

chat = ChatOpenAI(model_name="gpt-5-nano", temperature=1, streaming=True, callbacks=[StreamingStdOutCallbackHandler()])

examples = [
{
"question": "What do you know about France?",
"answer": """
Here is what I know:
Capital: Paris
Language: French
Food: Wine and Cheese
Currency: Euro
""",
},
{
"question": "What do you know about Italy?",
"answer": """
I know this:
Capital: Rome
Language: Italian
Food: Pizza and Pasta
Currency: Euro
""",
},
{
"question": "What do you know about Greece?",
"answer": """
I know this:
Capital: Athens
Language: Greek
Food: Souvlaki and Feta Cheese
Currency: Euro
""",
},
]

chat.predict("What do you know about korea?")
# Out:
# Korea can refer to two countries on the Korean Peninsula: South Korea (the Republic of Korea) and North Korea (the Democratic People’s Republic of Korea). Here’s a concise overview of both, plus some quick cultural notes.
#
# - Geography and people
#   - Located in East Asia on the Korean Peninsula, with the DMZ dividing the North and South.
#   - Korea has a long, mountainous terrain and a temperate climate with four seasons. Major cities include Seoul (South Korea) and Pyongyang (North Korea).
#   - The people are Korean; the language is Korean, written in Hangul. Dialects exist, but standard Korean is widely understood in both North and South.
#
# - Language
#   - Korean is the official language in both Koreas. Hangul (the Korean alphabet) is used in both countries.
#   - South Korea is highly multilingual in urban areas (English widely taught in schools). North Korea has less exposure to foreign languages due to its closed economy and regime.
#
# - History (very brief)
#   - Ancient kingdoms unified and then split into regional dynasties over centuries.
#   - 1910–1945: Korea was under Japanese rule.
#   - 1945: Liberation from Japan; the peninsula was divided into a Soviet-occupied north and American-occupied south.
#   - 1950–1953: Korean War; armistice signed in 1953, but no formal peace treaty—North and South remain technically at war.
#   - Postwar: South Korea developed into a high-tech, export-led economy; North Korea pursued a centralized, self-reliant system with a focus on military buildup.
#
# - Politics and economy (South vs North)
#   - South Korea: a democratic republic with a market economy. Known for advanced technology, electronics, cars, and a vibrant culture industry (K-pop, cinema). Major companies include Samsung, Hyundai, LG.
#   - North Korea: a single-party state with a centralized, state-controlled economy. Highly isolated internationally, with ongoing concerns around human rights and its nuclear program.
#   - Inter-Korean relations have fluctuated: periods of dialogue and cooperation interspersed with tension and sanctions.
#
# - Culture and cuisine
#   - Deep Confucian heritage shaping family life, education, and etiquette.
#   - Holidays: Seollal (Lunar New Year) and Chuseok (harvest festival) are major traditional celebrations.
#   - Modern culture: globally influential K-pop, Korean cinema (films like Parasite), TV dramas, and a thriving fashion scene.
#   - Cuisine highlights: kimchi (fermented vegetables, usually cabbage or radish), bibimbap (mixed rice with vegetables and meat), bulgogi (marinated beef), samgyeopsal (grilled pork belly), jjigae (stew). Meals often feature shared dishes and rice; etiquette emphasises sharing and coordinating to a group.
#
# - Notable places and travel
#   - South Korea: Seoul (palaces like Gyeongbokgung, modern districts like Gangnam), Busan (beaches and seafood), Jeju Island (volcanic landscapes), and the DMZ on guided tours.
#   - North Korea: Pyongyang’s monuments and mass games, historic sites like the Kumsusan Palace, and restricted, heavily supervised tourism.
#   - South Korea is generally traveler-friendly with developed infrastructure (KTX high-speed train network, easy transit, and English signage in major areas).
#
# - Quick facts you might find handy
#   - Time zone: Korea Standard Time (UTC+9).
#   - Currency: South Korea uses the won (KRW); North Korea uses the won (KPW) with strict controls and limited foreign exchange.
#   - Safety: South Korea is considered very safe for travelers; North Korea requires careful attention to government travel rules and the current political climate.
#
# If you’d like, tell me what specifically you’re curious about (history, culture, language, travel tips, current events, foods, or something else), or which Korea you mean (South, North, or both), and I can dive deeper.
# 'Korea can refer to two countries on the Korean Peninsula: South Korea (the Republic of Korea) and North Korea (the Democratic People’s Republic of Korea). Here’s a concise overview of both, plus some quick cultural notes.\n\n- Geography and people\n  - Located in East Asia on the Korean Peninsula, with the DMZ dividing the North and South.\n  - Korea has a long, mountainous terrain and a temperate climate with four seasons. Major cities include Seoul (South Korea) and Pyongyang (North Korea).\n  - The people are Korean; the language is Korean, written in Hangul. Dialects exist, but standard Korean is widely understood in both North and South.\n\n- Language\n  - Korean is the official language in both Koreas. Hangul (the Korean alphabet) is used in both countries.\n  - South Korea is highly multilingual in urban areas (English widely taught in schools). North Korea has less exposure to foreign languages due to its closed economy and regime.\n\n- History (very brief)\n  - Ancient kingdoms unified and then split into regional dynasties over centuries.\n  - 1910–1945: Korea was under Japanese rule.\n  - 1945: Liberation from Japan; the peninsula was divided into a Soviet-occupied north and American-occupied south.\n  - 1950–1953: Korean War; armistice signed in 1953, but no formal peace treaty—North and South remain technically at war.\n  - Postwar: South Korea developed into a high-tech, export-led economy; North Korea pursued a centralized, self-reliant system with a focus on military buildup.\n\n- Politics and economy (South vs North)\n  - South Korea: a democratic republic with a market economy. Known for advanced technology, electronics, cars, and a vibrant culture industry (K-pop, cinema). Major companies include Samsung, Hyundai, LG.\n  - North Korea: a single-party state with a centralized, state-controlled economy. Highly isolated internationally, with ongoing concerns around human rights and its nuclear program.\n  - Inter-Korean relations have fluctuated: periods of dialogue and cooperation interspersed with tension and sanctions.\n\n- Culture and cuisine\n  - Deep Confucian heritage shaping family life, education, and etiquette.\n  - Holidays: Seollal (Lunar New Year) and Chuseok (harvest festival) are major traditional celebrations.\n  - Modern culture: globally influential K-pop, Korean cinema (films like Parasite), TV dramas, and a thriving fashion scene.\n  - Cuisine highlights: kimchi (fermented vegetables, usually cabbage or radish), bibimbap (mixed rice with vegetables and meat), bulgogi (marinated beef), samgyeopsal (grilled pork belly), jjigae (stew). Meals often feature shared dishes and rice; etiquette emphasises sharing and coordinating to a group.\n\n- Notable places and travel\n  - South Korea: Seoul (palaces like Gyeongbokgung, modern districts like Gangnam), Busan (beaches and seafood), Jeju Island (volcanic landscapes), and the DMZ on guided tours.\n  - North Korea: Pyongyang’s monuments and mass games, historic sites like the Kumsusan Palace, and restricted, heavily supervised tourism.\n  - South Korea is generally traveler-friendly with developed infrastructure (KTX high-speed train network, easy transit, and English signage in major areas).\n\n- Quick facts you might find handy\n  - Time zone: Korea Standard Time (UTC+9).\n  - Currency: South Korea uses the won (KRW); North Korea uses the won (KPW) with strict controls and limited foreign exchange.\n  - Safety: South Korea is considered very safe for travelers; North Korea requires careful attention to government travel rules and the current political climate.\n\nIf you’d like, tell me what specifically you’re curious about (history, culture, language, travel tips, current events, foods, or something else), or which Korea you mean (South, North, or both), and I can dive deeper.'
