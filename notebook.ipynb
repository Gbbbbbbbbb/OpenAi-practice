# %%
from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import UnstructuredFileLoader
from langchain.text_splitter import CharacterTextSplitter

spliter = CharacterTextSplitter(
    separator="\n",
    chunk_size=600,
    chunk_overlap=100
)

loader= UnstructuredFileLoader("./files/chapter_one.docx")

len(loader.load_and_split(text_splitter=spliter))
# Out:
# Created a chunk of size 1208, which is longer than the specified 600
# Created a chunk of size 1376, which is longer than the specified 600
# Created a chunk of size 1064, which is longer than the specified 600
# Created a chunk of size 608, which is longer than the specified 600
# Created a chunk of size 856, which is longer than the specified 600
# Created a chunk of size 709, which is longer than the specified 600
# Created a chunk of size 920, which is longer than the specified 600
# Created a chunk of size 1126, which is longer than the specified 600
# Created a chunk of size 1407, which is longer than the specified 600
# Created a chunk of size 750, which is longer than the specified 600
# Created a chunk of size 1060, which is longer than the specified 600
# Created a chunk of size 879, which is longer than the specified 600
# Created a chunk of size 1035, which is longer than the specified 600
# Created a chunk of size 1255, which is longer than the specified 600
# Created a chunk of size 1424, which is longer than the specified 600
# Created a chunk of size 1272, which is longer than the specified 600
# Created a chunk of size 1303, which is longer than the specified 600
# Created a chunk of size 1099, which is longer than the specified 600
# Created a chunk of size 960, which is longer than the specified 600
# Created a chunk of size 728, which is longer than the specified 600
# Created a chunk of size 738, which is longer than the specified 600
# Created a chunk of size 960, which is longer than the specified 600
# Created a chunk of size 1065, which is longer than the specified 600
# Created a chunk of size 1243, which is longer than the specified 600
# Created a chunk of size 1396, which is longer than the specified 600
# Created a chunk of size 1490, which is longer than the specified 600
# 49
