# %%
from langchain.chat_models import ChatOpenAI
from langchain.callbacks import StreamingStdOutCallbackHandler
from langchain.prompts import PromptTemplate
from langchain.prompts.pipeline import PipelinePromptTemplate
from langchain.globals import set_llm_cache , set_debug
from langchain.cache import InMemoryCache

set_llm_cache(InMemoryCache())
set_debug(True)

chat = ChatOpenAI(model_name="gpt-5-nano", temperature=1,)##streaming=True, callbacks=[StreamingStdOutCallbackHandler()])

chat.predict("how do you make italian pasta")
# Out:
# 'Do you want to cook dried pasta or make fresh pasta from scratch? Here are both fast options plus some simple sauce ideas.\n\n1) Cooking dried pasta (store-bought)\n- Use a large pot of water, well salted (about 1 tablespoon salt per 4–5 liters water).\n- Add pasta and stir to prevent sticking.\n- Cook until al dente, per package instructions (usually 8–12 minutes for regular pasta; shorter for thinner shapes). Taste to check.\n- Reserve a small cup of the cooking water, then drain.\n- Toss with your sauce, adding a splash of the reserved water if needed to loosen.\n\n2) Making fresh pasta from scratch (egg pasta; serves 2–3)\n- Ingredients (basic): 200 g 00 flour or all-purpose flour, 2 large eggs, pinch of salt (optional 1 tbsp olive oil).\n- Method:\n  - Mound the flour on a clean surface, make a well in the center.\n  - Crack in the eggs, add salt. Beat eggs with a fork, gradually drawing flour into the center.\n  - When a shaggy dough forms, knead on the surface for about 10 minutes until smooth and elastic. If very sticky, sprinkle a little flour.\n  - Wrap and rest 30–60 minutes.\n  - Roll out thin (you can use a rolling pin or a pasta machine) to about 1–2 mm thick.\n  - Cut into your preferred shape (fettuccine, tagliatelle, pappardelle, or use sheets for lasagna).\n- Cook fresh pasta: boil in salted water 2–4 minutes until al dente. Fresh pasta cooks much faster than dried.\n\n3) Quick, simple sauces to pair with pasta\n- Aglio e olio: sauté sliced garlic in olive oil with chili flakes; toss with pasta and chopped parsley.\n- Butter and parmesan (for long shapes): add hot pasta to a skillet with a knob of butter; stir in grated Parmigiano-Reggiano.\n- Marinara: simmer canned tomatoes with garlic, olive oil, salt, and a pinch of sugar; finish with fresh basil.\n- Cacio e pepe (easy): toss pasta with plenty of grated Pecorino Romano, black pepper, and a little pasta water to emulsify.\n- Pesto: blend basil, pine nuts, garlic, Parmesan, olive oil; toss with hot pasta.\n\nTips\n- Salt the water until it tastes like seawater for best flavor.\n- Don’t add oil to the cooking water (it can make sauce cling less).\n- Reserve pasta water to adjust sauce consistency.\n- If you’re new to fresh pasta, start with 200 g flour + 2 eggs and scale up.\n\nWould you like a specific recipe for a particular pasta shape (like tagliatelle, spaghetti, or ravioli) or a step-by-step fresh-pasta recipe using a pasta machine?'

# %%
chat.predict("how do you make italian pasta")
# Out:
# 'Do you want to cook dried pasta or make fresh pasta from scratch? Here are both fast options plus some simple sauce ideas.\n\n1) Cooking dried pasta (store-bought)\n- Use a large pot of water, well salted (about 1 tablespoon salt per 4–5 liters water).\n- Add pasta and stir to prevent sticking.\n- Cook until al dente, per package instructions (usually 8–12 minutes for regular pasta; shorter for thinner shapes). Taste to check.\n- Reserve a small cup of the cooking water, then drain.\n- Toss with your sauce, adding a splash of the reserved water if needed to loosen.\n\n2) Making fresh pasta from scratch (egg pasta; serves 2–3)\n- Ingredients (basic): 200 g 00 flour or all-purpose flour, 2 large eggs, pinch of salt (optional 1 tbsp olive oil).\n- Method:\n  - Mound the flour on a clean surface, make a well in the center.\n  - Crack in the eggs, add salt. Beat eggs with a fork, gradually drawing flour into the center.\n  - When a shaggy dough forms, knead on the surface for about 10 minutes until smooth and elastic. If very sticky, sprinkle a little flour.\n  - Wrap and rest 30–60 minutes.\n  - Roll out thin (you can use a rolling pin or a pasta machine) to about 1–2 mm thick.\n  - Cut into your preferred shape (fettuccine, tagliatelle, pappardelle, or use sheets for lasagna).\n- Cook fresh pasta: boil in salted water 2–4 minutes until al dente. Fresh pasta cooks much faster than dried.\n\n3) Quick, simple sauces to pair with pasta\n- Aglio e olio: sauté sliced garlic in olive oil with chili flakes; toss with pasta and chopped parsley.\n- Butter and parmesan (for long shapes): add hot pasta to a skillet with a knob of butter; stir in grated Parmigiano-Reggiano.\n- Marinara: simmer canned tomatoes with garlic, olive oil, salt, and a pinch of sugar; finish with fresh basil.\n- Cacio e pepe (easy): toss pasta with plenty of grated Pecorino Romano, black pepper, and a little pasta water to emulsify.\n- Pesto: blend basil, pine nuts, garlic, Parmesan, olive oil; toss with hot pasta.\n\nTips\n- Salt the water until it tastes like seawater for best flavor.\n- Don’t add oil to the cooking water (it can make sauce cling less).\n- Reserve pasta water to adjust sauce consistency.\n- If you’re new to fresh pasta, start with 200 g flour + 2 eggs and scale up.\n\nWould you like a specific recipe for a particular pasta shape (like tagliatelle, spaghetti, or ravioli) or a step-by-step fresh-pasta recipe using a pasta machine?'
